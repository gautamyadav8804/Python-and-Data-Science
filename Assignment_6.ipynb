# %%
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
survey=  pd.read_csv('survey_results_public.csv')

# %%
survey
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
survey.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
survey.shape
# Out:
# (88883, 85)

# %%
survey.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
survey['Age1stCode']
# Out:
# 0         10
# 1         17
# 2         22
# 3         16
# 4         14
#         ...
# 88878    NaN
# 88879    NaN
# 88880    NaN
# 88881    NaN
# 88882     11
# Name: Age1stCode, Length: 88883, dtype: object

# %%
survey['Age1stCode'].isnull().sum()
# Out:
# 1249

# %%
survey.shape
# Out:
# (88883, 85)

# %%
survey['Age1stCode'].unique()
# Out:
# array(['10', '17', '22', '16', '14', '15', '11', '20', '13', '18', '12',
#        '19', '21', '8', '35', '6', '9', '29', '7', '5', '23', '30', nan,
#        '27', '24', 'Younger than 5 years', '33', '25', '26', '39', '36',
#        '38', '28', '31', 'Older than 85', '32', '37', '50', '65', '42',
#        '34', '40', '67', '43', '44', '60', '46', '45', '49', '51', '41',
#        '55', '83', '48', '53', '54', '47', '56', '79', '61', '68', '77',
#        '66', '52', '80', '62', '84', '57', '58', '63'], dtype=object)

# %%
var=survey['Age1stCode']=='Older than 85'
survey.loc[var,('Age1stCode')]=86

# %%
var=survey['Age1stCode']=='Younger than 5 years'
survey.loc[var,('Age1stCode')]= 4

# %%
survey['Age1stCode'].isnull().sum()
# Out:
# 1249

# %%
survey['Age1stCode']=survey['Age1stCode'].astype('float')

# %%
survey['Age1stCode'].unique()
# Out:
# array([10., 17., 22., 16., 14., 15., 11., 20., 13., 18., 12., 19., 21.,
#         8., 35.,  6.,  9., 29.,  7.,  5., 23., 30., nan, 27., 24.,  4.,
#        33., 25., 26., 39., 36., 38., 28., 31., 86., 32., 37., 50., 65.,
#        42., 34., 40., 67., 43., 44., 60., 46., 45., 49., 51., 41., 55.,
#        83., 48., 53., 54., 47., 56., 79., 61., 68., 77., 66., 52., 80.,
#        62., 84., 57., 58., 63.])

# %%
survey['Age1stCode'].dtype
# Out:
# dtype('float64')

# %%
import numpy as np
np.mean(survey['Age1stCode'])
# Out:
# 15.409395896569825

# %%
plt.figure(figsize=(16,5))
sns.countplot(x='Age1stCode',data=survey ,order= survey['Age1stCode'].value_counts().iloc[:20].index)
# Out:
# <AxesSubplot:xlabel='Age1stCode', ylabel='count'>

# %%
df[percent] = (df['column_name'] / df['column_name'].sum()) * 100
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-56b238d08b17> in <module>
# ----> 1 df[percent] = (df['column_name'] / df['column_name'].sum()) * 100
#
# NameError: name 'df' is not defined

# %%
survey[percent] = ([''].sum()) * 100

# %%
survey[LanguageWorkedWith].spilt(';')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-f726fccfad15> in <module>
# ----> 1 survey[LanguageWorkedWith].spilt(';')
#
# NameError: name 'LanguageWorkedWith' is not defined
